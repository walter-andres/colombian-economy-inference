# %% [markdown]
# # Reconocimiento de Audio, Transformada de Fourier y su aplicación en RNNs

# %% [markdown]
# #1. Onda Sonora (Sonido)

# %% [markdown]
# Es una vibración que se propaga a través de un medio (como el aire, el agua o un sólido) que puede ser percibida por el oído humano y otras especies.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Herramienta interactiva: https://phet.colorado.edu/sims/html/sound-waves/latest/sound-waves_all.html
#
# - Frecuencia: El número de oscilaciones o ciclos que ocurren en una onda sonora por segundo, medido en Hercios (Hz). La frecuencia de una onda sonora determina el tono del sonido: las frecuencias más altas producen sonidos más agudos y las frecuencias más bajas producen sonidos más graves.
# - Longitud de onda (wavelenght): La distancia física entre dos puntos consecutivos en fase de una onda, como de cresta a cresta o de valle a valle. La longitud de onda de una onda sonora (λ) es inversamente proporcional a la frecuencia y está directamente relacionada con la velocidad del sonido (c) y la frecuencia de la onda (f) mediante la fórmula λ=c/f.
# - La amplitud de una onda sonora representa el desplazamiento máximo de partículas de su posición de equilibrio debido al paso de la onda. En las ondas sonoras, la amplitud está relacionada con el volumen del sonido, y amplitudes mayores producen sonidos más fuertes.
# - Velocidad: La velocidad a la que una onda sonora viaja a través de un medio. La velocidad del sonido varía según el medio y sus propiedades (p. ej., densidad, temperatura y elasticidad), siendo más rápida en sólidos, más lenta en líquidos y más lenta en gases.
# - Intensidad: La potencia transportada por una onda sonora por unidad de área, medida en Watts por metro cuadrado (W/m2). La intensidad es una medida de la energía de la onda sonora y está relacionada tanto con su amplitud como con la distancia desde la fuente, lo que influye en el volumen que se percibe el sonido.
# - Fase: describe la posición de un punto en el tiempo en un ciclo de forma de onda. En el contexto de múltiples ondas que interactúan, las diferencias de fase pueden provocar fenómenos como interferencias constructivas o destructivas, afectando significativamente la amplitud e intensidad del sonido resultante.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #2. Transformada de Fourier (TF)

# %% [markdown]
# Descompone una señal (como un sonido, una imagen o cualquier onda) en sus frecuencias básicas, revelando "qué ingredientes" la forman.
#
# Aplicaciones:
#
# - En audio: para ecualizar música, reconocer voces o comprimir archivos (como MP3).
#
# - En imágenes: para aplicar filtros, eliminar ruido o comprimir (como JPEG).
#
# - En ingeniería: analizar vibraciones, señales de radio, etc.

# %% [markdown]
# ## Fórmula

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **1. f(t) (Señal en el tiempo)**
#   - Qué es: La señal que quieres analizar (ej: un sonido, una onda de radio, un ECG).
#   - Dominio: Está en función del tiempo (t). Por ejemplo, podría ser la amplitud de un sonido en cada instante.
#
# **2. F(ω) (Transformada de Fourier)**
#   - Qué es: El resultado de la operación; representa la señal en el dominio de la frecuencia.
#   - Interpretación: Nos dice "qué frecuencias" componen f(t) y con qué intensidad (amplitud).
#       - Si F(ω) tiene un pico en ω=100 rad/s, significa que f(t) contiene una oscilación fuerte a esa frecuencia.
#
# **3. e −iωt (Núcleo exponencial complejo)**
#   - Qué es: Una onda compleja (combinación de senos y cosenos) a frecuencia ω.
#   - Fórmula de Euler: e −iωt=cos(ωt)−isin(ωt).
#     - La parte real (cos) y la imaginaria (sin) actúan como "filtros" que detectan cuánto de f(t) coincide con la frecuencia w
#
# **4. ω (Frecuencia angular)**
#   - Qué es: La frecuencia de análisis (en radianes por segundo).
#   - Relación con Hertz (Hz): ω=2πf, donde f es la frecuencia en Hz.
#
# **5. ∞ ∫ −∞ (Integral sobre todo el tiempo)**
#   - Qué hace: Evalua o promedia la contribución de f(t) a la frecuencia ω a lo largo de todo su historial temporal.
#   - En la práctica: Para señales no periódicas (como un audio finito), se usan límites finitos o la Transformada Discreta de Fourier (DFT).
#
# **Interpretación de forma resumida:**
#
# La ecuación multiplica f(t) por una onda pura a frecuencia ω y luego integra.
#
# - Si f(t) tiene una componente que "vibra" igual que e −iωt, la integral dará un valor grande (pico en F(ω)).
#
# - Si no hay coincidencia, la integral será cercana a cero.
#
# **Ejemplo con sonido**
# Podemos imaginar a f(t) como un acorde de piano (3 notas). La Transformada de Fourier F(ω) mostrará 3 picos en las frecuencias de esas notas.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.fft import fft

# Parámetros de la señal
sampling_rate = 1000  # Frecuencia de muestreo (muestras por segundo)
duration = 1          # Duración de la señal en segundos
frequency1 = 50       # Frecuencia de la primera onda senoidal
frequency2 = 120      # Frecuencia de la segunda onda senoidal

# Generar el eje de tiempo
t = np.linspace(0, duration, sampling_rate * duration, endpoint=False)

# Generar las dos ondas senoidales
signal1 = np.sin(2 * np.pi * frequency1 * t)
signal2 = 0.5 * np.sin(2 * np.pi * frequency2 * t) # Amplitud reducida para la segunda onda

# Combinar las ondas para crear la señal compuesta
combined_signal = signal1 + signal2

# Visualizar la señal en el dominio del tiempo
plt.figure(figsize=(10, 4))
plt.plot(t, combined_signal)
plt.title('Señal Combinada en el Dominio del Tiempo')
plt.xlabel('Tiempo [s]')
plt.ylabel('Amplitud')
plt.grid(True)
plt.show()

# Aplicar la Transformada de Fourier
# La Transformada de Fourier Rápida (FFT) es una implementación eficiente
fft_result = fft(combined_signal)

# Calcular las frecuencias correspondientes
n = len(combined_signal)
frequencies = np.fft.fftfreq(n, 1/sampling_rate)

# Tomar la magnitud de la parte positiva del espectro de frecuencia
# Como la señal es real, el espectro es simétrico. Solo necesitamos la primera mitad.
positive_frequencies = frequencies[:n//2]
magnitude_spectrum = np.abs(fft_result)[:n//2] * 2 / n # Normalizar y tomar la magnitud

# Visualizar el espectro de frecuencia
plt.figure(figsize=(10, 4))
plt.plot(positive_frequencies, magnitude_spectrum)
plt.title('Espectro de Frecuencia (Magnitud)')
plt.xlabel('Frecuencia [Hz]')
plt.ylabel('Magnitud')
plt.grid(True)
plt.xlim(0, max(frequency1, frequency2) + 50) # Ajustar el límite del eje x para mejor visualización
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import numpy as np
#       2 import matplotlib.pyplot as plt
#       3 from scipy.fft import fft
#
# ModuleNotFoundError: No module named 'numpy'

# %% [markdown]
# # 3. Uso en Redes Recurrentes para Reconocimiento de Audio y Aplicación de la TF

# %% [markdown]
# # 3.1 Modelo de Predicción secuencial de onda sonoda (sequence prediction)

# %% [markdown]
# - El siguiente Modelo realiza una predicción del **siguiente vector de frecuencias** dado el historial. Ese “siguiente vector” es básicamente cómo sonará el audio en el próximo instante, y esa predicción sirve para comparar con el patrón real del audio y así saber si se parece a un sonido que ya conocemos.
#
# - Es como si la RNN fuera un fan de una canción que tararea la siguiente nota antes de que suene. Si acierta muchas veces, es porque conoce bien la canción

# %% [markdown]
# ## Conceptos clave:
# - Transformada de Fourier: Matemáticamente descompone una señal en sus frecuencias componentes.
#
# - Espectrograma: Representación visual de las frecuencias de una señal a lo largo del tiempo

# %% [markdown]
# ## Importamos líbrerías necesarias

# %%
# Importamos las librerías necesarias
import numpy as np
import matplotlib.pyplot as plt
import librosa  # Para procesamiento de audio
import librosa.display  # Para visualización
import tensorflow as tf  # Para la red neuronal
from sklearn.model_selection import train_test_split  # Para dividir datos

# %% [markdown]
# ##1. Descargar y preparar un audio de ejemplo
#
# - Usaremos un audio corto de ejemplo disponible online.

# %%
# https://www.soundhelix.com/examples/mp3/SoundHelix-Song-1.mp3
audio = "SoundHelix-Song-1.mp3"

# Cargamos el audio con librosa (esto descargará el archivo temporalmente)
# librosa.load carga el audio y lo convierte a un array numpy
# sr=None mantiene la frecuencia de muestreo original
# duration=10 limita a solo los primeros 10 segundos para simplificar
y, sr = librosa.load(audio, sr=None, duration=10)

# sr = 44100 Hz (muestras/segundo)
#y = 44100 * 10 = 441,000 muestras

# Mostramos información básica
print(f"Duración: {len(y)/sr} segundos")
print(f"Frecuencia de muestreo: {sr} Hz")
print(f"Número de muestras: {len(y)}")
# Out:
# Duración: 10.0 segundos
# Frecuencia de muestreo: 44100 Hz
# Número de muestras: 441000

# %% [markdown]
# ##2. Visualización de la forma de onda

# %%
plt.figure(figsize=(12, 4))
librosa.display.waveshow(y, sr=sr)
plt.title("Forma de onda del audio")
plt.xlabel("Tiempo (s)")
plt.ylabel("Amplitud")
plt.show()

# %% [markdown]
# ##3. Transformada de Fourier y Espectrograma
# - La Transformada de Fourier nos permite ver qué frecuencias están presentes en el audio.
#
# - Un espectrograma es una representación visual de las frecuencias que componen una señal sonora (u otra señal en el dominio de la frecuencia) en función del tiempo. Es una herramienta fundamental en campos como el procesamiento de señales, acústica, música, telecomunicaciones y análisis de vibraciones

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Calculamos la Transformada Rápida de Fourier (FFT)
# FFT es un algoritmo eficiente para calcular la Transformada de Fourier
fft = np.fft.fft(y)

# Calculamos la magnitud
magnitude = np.abs(fft)

# Creamos el eje de frecuencias
frequency = np.linspace(0, sr, len(magnitude))

# Solo mostramos la primera mitad (por simetría)
left_frequency = frequency[:int(len(frequency)/2)]
left_magnitude = magnitude[:int(len(magnitude)/2)]

# Graficamos
plt.figure(figsize=(12, 4))
plt.plot(left_frequency, left_magnitude)
plt.title("Espectro de Frecuencia")
plt.xlabel("Frecuencia (Hz)")
plt.ylabel("Magnitud")
plt.show()

# %% [markdown]
# ##4. Espectrograma (FFT en el tiempo)
# Un espectrograma muestra cómo las frecuencias cambian con el tiempo.

# %%
# Calculamos el espectrograma usando STFT (Short-Time Fourier Transform)
n_fft = 2048 # tamaño de la ventana
hop_length = 512 # el paso entre ventanas

stft = librosa.stft(y, n_fft=n_fft, hop_length=hop_length)
spectrogram = np.abs(stft)  # Convertimos a magnitud

# Convertimos a decibelios para mejor visualización
log_spectrogram = librosa.amplitude_to_db(spectrogram)

# Mostramos el espectrograma
plt.figure(figsize=(12, 6))
librosa.display.specshow(log_spectrogram, sr=sr, hop_length=hop_length, x_axis="time", y_axis="log")
plt.colorbar(format="%+2.0f dB")
plt.title("Espectrograma")
plt.show()

# %% [markdown]
# ##5. Extracción de características "Features" (MFCCs)
# Los coeficientes cepstrales de frecuencia Mel (o escala Mel) (MFCCs) son características comúnmente usadas en reconocimiento de audio.
#
# - La escala Mel escala perceptual que mide el tono de un sonido de la manera en que el oído humano lo percibe.
#   - Es un puente entre la medición física del sonido y su percepción subjetiva por parte de los humanos, y es la base tecnológica que permite que las máquinas "entiendan" nuestra voz y el mundo sonoro que nos rodea.
#
# - El ceptro (cepstrum) es la transformada inversa de Fourier del logaritmo del espectro de una señal, usado para separar componentes como fuente y filtro en audio

# %% [markdown]
# **¿Qué son los MFCCs?**
#
# - El oído humano no escucha todas las frecuencias igual (somos más sensibles a unas que a otras), usamos la escala Mel, que se parece más a cómo percibimos el sonido.
# - Los MFCCs son como "huellas digitales" del audio, pequeños vectores de números que describen cómo suena un fragmento de música o voz
# - Son coeficientes que representan la forma general del espectro de frecuencia de un sonido.
# - Cada MFCC es como una feature (característica) del dataset
# - Capturan:
#
#   - Las características espectrales importantes
#
#   - De una manera que se asemeja a cómo percibimos el sonido los humanos
#
# **Analogía simple:**
#
# - Imagina que quieres describir una canción a alguien:
#
# - No le dices "hay un tono a 1000Hz con amplitud X"
#
# - Sino algo como "suena agudo, con graves fuertes, un poco nasal..."
# Los MFCCs hacen algo similar: convierten datos técnicos del audio en características que tienen más sentido perceptual.

# %%
# Extraemos MFCCs (generalmente se usan 13-40 coeficientes)
n_mfcc = 20
mfccs = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=n_mfcc)

# Mostramos los MFCCs
plt.figure(figsize=(12, 6))
librosa.display.specshow(mfccs, sr=sr, hop_length=hop_length, x_axis="time")
plt.colorbar()
plt.title("MFCCs")
plt.show()

# %% [markdown]
# ##6. Preparación de datos para la RNN
# Para simplificar, simularemos tener varios audios (en un caso real necesitariamos una base de datos)

# %%
# Simulamos tener múltiples muestras dividiendo el audio en segmentos
segment_length = sr * 2  # 2 segundos
num_segments = len(y) // segment_length

# Creamos segmentos y calculamos sus MFCCs
X = []
for i in range(num_segments):
    start = i * segment_length
    end = start + segment_length
    segment = y[start:end]

    # Calculamos MFCCs para el segmento
    mfcc = librosa.feature.mfcc(y=segment, sr=sr, n_mfcc=n_mfcc)
    X.append(mfcc.T)  # Transponemos para tener (time_steps, features)

# Convertimos a numpy array
X = np.array(X)

# Simulamos etiquetas (0 para este audio, en un caso real tendrías diferentes)
y_labels = np.zeros(num_segments)

# Dividimos en entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(
    X, y_labels, test_size=0.2, random_state=42)

print(f"Forma de X_train: {X_train.shape}")  # (muestras, time_steps, features)
print(f"Forma de X_test: {X_test.shape}")
# Out:
# Forma de X_train: (4, 173, 20)
# Forma de X_test: (1, 173, 20)

# %% [markdown]
# ##7. Construcción del modelo RNN
# Usaremos una RNN simple con capas LSTM (que son buenas para aprender patrones temporales).

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

# Parámetros
input_shape = X_train.shape[1:]  # (time_steps, n_mfcc)
num_classes = 1  # Solo estamos reconociendo un audio en este ejemplo

# Construimos el modelo
model = Sequential([
    # Capa LSTM con 64 unidades
    # return_sequences=True pasa todas las salidas, no solo la última
    LSTM(64, input_shape=input_shape, return_sequences=True),
    Dropout(0.2),  # Regularización para prevenir sobreajuste

    # Segunda capa LSTM
    LSTM(64),
    Dropout(0.2),

    # Capa densa final con activación sigmoide (para clasificación binaria)
    Dense(num_classes, activation="sigmoid")
])

# Compilamos el modelo
model.compile(
    optimizer="adam",
    loss="binary_crossentropy",  # Para clasificación binaria
    metrics=["accuracy"]
)

model.summary()
# Out:
# Model: "sequential_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_10 (LSTM)                  │ (None, 173, 64)        │        21,760 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 173, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_11 (LSTM)                  │ (None, 64)             │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 54,849 (214.25 KB)
#  Trainable params: 54,849 (214.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ##8. Entrenamiento del modelo

# %%
# Entrenamos el modelo
history = model.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=10,  # Número de pasadas por todos los datos
    batch_size=16  # Número de muestras por actualización de gradiente
)
# Out:
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 11s 11s/step - accuracy: 0.0000e+00 - loss: 0.8048 - val_accuracy: 1.0000 - val_loss: 0.6607
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 503ms/step - accuracy: 1.0000 - loss: 0.6281 - val_accuracy: 1.0000 - val_loss: 0.5425
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 605ms/step - accuracy: 1.0000 - loss: 0.5569 - val_accuracy: 1.0000 - val_loss: 0.4497
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 570ms/step - accuracy: 1.0000 - loss: 0.4219 - val_accuracy: 1.0000 - val_loss: 0.3729
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 756ms/step - accuracy: 1.0000 - loss: 0.3521 - val_accuracy: 1.0000 - val_loss: 0.3076
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 537ms/step - accuracy: 1.0000 - loss: 0.2952 - val_accuracy: 1.0000 - val_loss: 0.2532
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 601ms/step - accuracy: 1.0000 - loss: 0.2512 - val_accuracy: 1.0000 - val_loss: 0.2077
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 587ms/step - accuracy: 1.0000 - loss: 0.2007 - val_accuracy: 1.0000 - val_loss: 0.1699
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 543ms/step - accuracy: 1.0000 - loss: 0.1304 - val_accuracy: 1.0000 - val_loss: 0.1385
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step - accuracy: 1.0000 - loss: 0.1391 - val_accuracy: 1.0000 - val_loss: 0.1121

# %% [markdown]
# ##9. Evaluación del modelo

# %%
# Graficamos precisión y pérdida
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history["accuracy"], label="Train Accuracy")
plt.plot(history.history["val_accuracy"], label="Validation Accuracy")
plt.legend()
plt.title("Precisión")

plt.subplot(1, 2, 2)
plt.plot(history.history["loss"], label="Train Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")
plt.legend()
plt.title("Pérdida")
plt.show()

# %% [markdown]
# # 📈 Análisis del Entrenamiento
#
# ## ✅ **Aspectos Positivos**
# - **Aprendizaje exitoso:** Ambas precisiones (Train y Validation) suben constantemente, lo que demuestra que el modelo capta los patrones de los datos.
#
# ## ⚠️ **Posible: Overfitting**
# - A partir de la **época 4-5**, se observa una **brecha creciente** entre las curvas de entrenamiento y validación, especialmente en la pérdida (Loss).
# - Esto significa que el modelo **memoriza** el conjunto de entrenamiento pero pierde capacidad para generalizar en datos nuevos.

# %% [markdown]
# # 3.2 Mini-Shazam

# %% [markdown]
# Teniendo en cuenta lo anterior....vamos a construir un Mini-Shazam.

# %%
import librosa
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Input
import matplotlib.pyplot as plt
# Padding para secuencias de distinta longitud
from tensorflow.keras.preprocessing.sequence import pad_sequences
# Para que todas las secuencias tengan la misma dimensión de tiempo

# 1. Cargar archivo de audio

# https://www.soundhelix.com/examples/mp3/SoundHelix-Song-1.mp3
audio = "SoundHelix-Song-1.mp3"

# Cargamos la canción completa
y, sr = librosa.load(audio, sr=22050) # sr = Frecuencia de Muestreo = número de muestras de audio por segundo
# sr = 22.050 Hz
print(f"Duración de la canción: {len(y)/sr:.2f} segundos o 6:12 Min")

# 2. Generar fragmentos positivos y negativos

# Fragmentos Positivos (X_pos): Son segmentos del audio que SI contienen el patrón a reconocer
# Fragmentos Negativos (X_neg): Son segmentos de audio que NO contienen ese patrón

# Fragmento positivo: seleccionamos 5 segundos de la canción
start = sr * 30   # desde el segundo 30
end = start + sr * 5
fragmento = y[start:end]

# Generamos características (MFCCs)
mfcc_pos = librosa.feature.mfcc(y=fragmento, sr=sr, n_mfcc=20)
X_pos = mfcc_pos.T
# transpuesta para pasar de formato (n_mfcc, frames) a (frames, n_mfcc)
# Cada fila = un instante de tiempo (frame)
# Cada columna = un feature (los coeficientes MFCC)

# Fragmento Negativo: ruido aleatorio con la misma duración
ruido = np.random.normal(0, 1, fragmento.shape)
mfcc_neg = librosa.feature.mfcc(y=ruido, sr=sr)
X_neg = mfcc_neg.T

# 3. Creamos el Dataset (Tensor)

X = [X_pos, X_neg]
y_labels = [1, 0]   # 1: pertenece, 0: no pertenece

# X_pos y X_neg) son matrices de distinto tamaño en el eje del tiempo
# porque cada señal de audio puede tener distinta duración
X_padded = pad_sequences(X, padding="post", dtype="float32") # redimensionamos
y_array = np.array(y_labels)
print("Shape del dataset:", X_padded.shape)
# Tendremos un dataset de (2, 216, 20): Tensor 3D (N, tiempo, features)
# 2 = número de ejemplos en el dataset (1 y 0)
# 216 = longitud temporal máxima encontrada (frames de tiempo) o ventanas de tiempo
# 20 = número de features por frame

# 4. Modelo RNN (LSTM)

model = Sequential([
    # Capa de entrada: recibe tensores 2D por cada ejemplo
    Input(shape=(X_padded.shape[1], X_padded.shape[2])),
    # Capa recurrente LSTM con 32 unidades. Recibe el Tensor 3D
    # Cada unidad tiene varias compuertas (input gate, forget gate, output gate) y una celda de memoria
    # “neurona + memoria interna + compuertas
    LSTM(32),
    # Capa densa final con 1 neurona y activación sigmoide para clasificación binaria
    Dense(1, activation="sigmoid")
])

model.compile(optimizer="adam", loss="binary_crossentropy", metrics=["accuracy"])
model.summary()

# 5. Entrenamiento

history = model.fit(X_padded, y_array, epochs=20, verbose=1, validation_split=0.5)

# 6. Predicción de prueba

pred_pos = model.predict(np.expand_dims(X_pos, axis=0))
pred_neg = model.predict(np.expand_dims(X_neg, axis=0))

print("\nPredicción fragmento de la canción:", pred_pos[0][0])
print("Predicción ruido (no pertenece):", pred_neg[0][0])


# 7. Evaluación

plt.figure(figsize=(12,4))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Entrenamiento')
plt.plot(history.history['val_loss'], label='Validación')
plt.title('Pérdida durante el entrenamiento')
plt.xlabel('Épocas')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Entrenamiento')
plt.plot(history.history['val_accuracy'], label='Validación')
plt.title('Precisión durante el entrenamiento')
plt.xlabel('Épocas')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Duración de la canción: 372.72 segundos o 6:12 Min
# Shape del dataset: (2, 216, 20)
# Model: "sequential_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_12 (LSTM)                  │ (None, 32)             │         6,784 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 6,817 (26.63 KB)
#  Trainable params: 6,817 (26.63 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 1.0000 - loss: 0.3561 - val_accuracy: 1.0000 - val_loss: 0.4410
# Epoch 2/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step - accuracy: 1.0000 - loss: 0.2953 - val_accuracy: 1.0000 - val_loss: 0.4430
# Epoch 3/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 1.0000 - loss: 0.2504 - val_accuracy: 1.0000 - val_loss: 0.4446
# Epoch 4/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 1.0000 - loss: 0.2189 - val_accuracy: 1.0000 - val_loss: 0.4459
# Epoch 5/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step - accuracy: 1.0000 - loss: 0.1958 - val_accuracy: 1.0000 - val_loss: 0.4469
# Epoch 6/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 1.0000 - loss: 0.1778 - val_accuracy: 1.0000 - val_loss: 0.4477
# Epoch 7/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 1.0000 - loss: 0.1633 - val_accuracy: 1.0000 - val_loss: 0.4484
# Epoch 8/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 1.0000 - loss: 0.1511 - val_accuracy: 1.0000 - val_loss: 0.4489
# Epoch 9/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step - accuracy: 1.0000 - loss: 0.1406 - val_accuracy: 1.0000 - val_loss: 0.4493
# Epoch 10/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step - accuracy: 1.0000 - loss: 0.1314 - val_accuracy: 1.0000 - val_loss: 0.4497
# Epoch 11/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 1.0000 - loss: 0.1232 - val_accuracy: 1.0000 - val_loss: 0.4500
# Epoch 12/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 1.0000 - loss: 0.1160 - val_accuracy: 1.0000 - val_loss: 0.4504
# Epoch 13/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 1.0000 - loss: 0.1095 - val_accuracy: 1.0000 - val_loss: 0.4509
# Epoch 14/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 1.0000 - loss: 0.1036 - val_accuracy: 1.0000 - val_loss: 0.4513
# Epoch 15/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 1.0000 - loss: 0.0983 - val_accuracy: 1.0000 - val_loss: 0.4517
# Epoch 16/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step - accuracy: 1.0000 - loss: 0.0932 - val_accuracy: 1.0000 - val_loss: 0.4521
# Epoch 17/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 1.0000 - loss: 0.0885 - val_accuracy: 1.0000 - val_loss: 0.4525
# Epoch 18/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 1.0000 - loss: 0.0839 - val_accuracy: 1.0000 - val_loss: 0.4528
# Epoch 19/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 1.0000 - loss: 0.0795 - val_accuracy: 1.0000 - val_loss: 0.4532
# Epoch 20/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 264ms/step - accuracy: 1.0000 - loss: 0.0753 - val_accuracy: 1.0000 - val_loss: 0.4536
# WARNING:tensorflow:5 out of the last 9 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7b05338cf600> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
#
# Predicción fragmento de la canción: 0.93115896
# Predicción ruido (no pertenece): 0.36465394

# %%
from google.colab import userdata
import os
import json
from openai import OpenAI

# Recuperar el token desde los secretos de Colab
hf_token = userdata.get('GPT-OSS')

# Configurarlo como variable de entorno (opcional pero útil)
os.environ['HF_TOKEN'] = hf_token

# Crear cliente con el token sin mostrarlo en el código
client = OpenAI(
    base_url="https://router.huggingface.co/v1",
    api_key=os.environ["HF_TOKEN"],
)

# Guardar history
with open("history.json", "w") as f:
    json.dump(history.history, f)

# --- Cargar history.json ---
with open("history.json", "r") as f:
    history_data = json.load(f)

# --- Mandar los datos al LLM ---
completion = client.chat.completions.create(
    model="openai/gpt-oss-20b",
    messages=[
        {"role": "system", "content": "Eres un experto en deep learning."},
        {"role": "user", "content": f"Interpreta estos resultados de entrenamiento:\n{history_data}"}
    ],
)

# Mostrar la respuesta
print(completion.choices[0].message.content)
# Out:
# ## Interpretación de los resultados
#
# | Métrica | Valor inicial | Valor final | Típico comportamiento | Comentario |
# |---------|---------------|-------------|-----------------------|------------|
# | **Training accuracy** | 1.0 | 1.0 | Debería subir hasta 1.0;  | Se alcanza 1.0 desde el primer epoch.  |
# | **Training loss** | 0.356 | 0.075 | Debería caer de forma continua. | Disminuye de forma gradual; el modelo sigue aprendiendo. |
# | **Validation accuracy** | 1.0 | 1.0 | Idealmente debería mantenerse estable. | También 1.0 desde el primer epoch. |
# | **Validation loss** | 0.441 | 0.454 | Una ligera tendencia a subir indica “sobre‑entrenamiento”  | Los valores se mantienen prácticamente constantes (≈ 0.45). |
#
# ### 1. Qué está pasando
#
# 1. **Exactitud perfecta en entrenamiento y validación**
#    - Cuando ambos (training y validation) alcanzan 1.0 desde el primer epoch, es señal de que el modelo **memoriza** el dataset o que el problema es trivial.
#    - Posibles causas:
#      - **Datos duplicados** (las mismas instancias aparecen en entrenamiento y validación).
#      - **Etiqueta errónea o “leakage”** (la etiqueta está presente en las características, por ejemplo, un ID codificado en una columna de entrada).
#      - **Dataset extremadamente pequeño o bajo la complejidad del modelo** (por ejemplo, un modelo con pocas capas y pocos parámetros frente a solo unas pocas clases).
#
# 2. **Pérdida de validación estable**
#    - La pérdida validación se mantiene bastante constante (~ 0.45) y **no mejora**.
#    - La pérdida de entrenamiento disminuye (de 0.36 a 0.075), lo que indica que el modelo sigue reduciendo errores sobre los datos de entrenamiento.
#    - Esto es típico de **sobre‑entrenamiento**: el modelo se ajusta bien a los datos de entrenamiento pero no logra “generalizar” más allá, aunque parece que ya lo hace (accuracy 1.0).
#    - En muchos casos la pérdida valida puede bajar y luego subir; aquí no hay descenso, lo cual es raro cuando la exactitud ya es perfecta.
#
# ### 2. Posibles interpretaciones
#
# | Hipótesis | Evidencia | Acción recomendada |
# |-----------|-----------|--------------------|
# | **El problema es trivial** (p.ej. separar dos clases con una característica distinta) | Accuracy 1.0 con mínima variación de loss | Revisa el número de clases, la diversidad de muestras y la distribución de clases. |
# | **Dataset pequeño y con duplicados** | Accuracy 1.0 desde el inicio | Revisa que el split no comparta instancias entre training/validation. |
# | **Datos con “label leakage”** | Accuracy perfecta a pesar de loss > 0.4 | Examina todas las columnas de entrada para detectar si alguna contiene la etiqueta (ID codificado, etc.). |
# | **Sobrecarga de modelo con datos limitados** | Loss de entrenamiento sigue bajando, pero val_loss constante | Reduce capacidad, añade regularización (dropout, L2) o detén entrenamiento temprano. |
# | **Errores en la métrica de evaluación** | Val_accuracy calculada de forma errónea (p.ej. no usa `argmax`) | Verifica que la métrica esté correctamente implementada. |
#
# ### 3. Qué hacer a continuación
#
# | Paso | Descripción | Herramienta/Recurso |
# |------|-------------|--------------------|
# | **1. Revisar el split** | Asegúrate de que `train/test` se realice sobre *conjuntos distintos*. Usa `sklearn.model_selection.train_test_split(..., shuffle=True)` y verifica las ID de cada muestra. | Jupyter Notebook, pandas |
# | **2. Inspecciones de datos** | - Hacer histogramas de cada característica.<br>- Chequear si alguna columna contiene la etiqueta. | Seaborn, pandas |
# | **3. Analizar métricas** | Calcular `macro_f1`, precision, recall. Si son 1.0 también, confirma si el modelo realmente “aprende” o simplemente está etiquetado (por ejemplo, `class_weight=1` en todo). | sklearn.metrics |
# | **4. Añadir regularización** | Dropout (p.ej. 0.5), L2 weight decay, batch normalization. | Keras `tf.keras.layers.Dropout` |
# | **5. Early Stopping** | Establecer `patience=5`, monitorear `val_loss`. | `tf.keras.callbacks.EarlyStopping` |
# | **6. Evaluar varianza** | Train con 5‑fold CV y comparar distribución de accuracies. | sklearn.model_selection.KFold |
# | **7. Revisar la arquitectura** | Si usas un modelo grande (VGG, ResNet) intenta un `DenseNet` más sencillo. | TensorFlow, PyTorch |
#
# ### 4. Mensaje clave
#
# > **La perfección en la exactitud no siempre indica buen modelo**. Cuando el modelo obtiene 100 % en ambos conjuntos de datos desde el primer epoch y la pérdida valida no mejora, la causa más habitual es **sobre‑entrenamiento con datos poco representativos** o **problemas de pre‑procesamiento** (duplicados, leakage).
# > Asegúrate de que el dataset sea suficientemente grande y diverso, de que la división entre entrenamiento y validación sea correcta, y de que no haya información “entrenada” inadvertidamente. Después de limpiar los datos, considera disminuir la complejidad del modelo o aplicar regularización antes de volver a entrenar.
#
# Con estos cambios deberías ver una caída en la pérdida de validación y un ajuste más realista de la exactitud. ¡Éxito con el fine‑tuning!
