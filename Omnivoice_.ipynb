# %% [markdown]
# # **Installing Python 3.10.11**

# %%
# !sudo apt-get update -y
# !sudo apt-get install python3.10 python3.10-distutils python3.10-venv -y
# !curl -sS https://bootstrap.pypa.io/get-pip.py | python3.10
# !python3.10 --version
# Out:
# Get:1 https://cli.github.com/packages stable InRelease [3,917 B]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:4 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [88.5 kB]
# Get:5 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:6 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [2,497 kB]
# Get:8 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:10 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [9,989 kB]
# Get:11 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Get:12 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [3,889 kB]
# Hit:13 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:14 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Hit:15 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:16 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 Packages [38.8 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [4,221 kB]
# Get:18 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,963 kB]
# Get:19 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,311 kB]
# Get:20 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [6,917 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,622 kB]
# Get:22 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [7,125 kB]
# Fetched 41.1 MB in 4s (11.6 MB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# Note, selecting 'python3-distutils' instead of 'python3.10-distutils'
# python3-distutils is already the newest version (3.10.8-1~22.04).
# python3-distutils set to manually installed.
# python3.10 is already the newest version (3.10.12-1~22.04.15).
# python3.10 set to manually installed.
# The following NEW packages will be installed:
#   python3-pip-whl python3-setuptools-whl python3.10-venv
# 0 upgraded, 3 newly installed, 0 to remove and 70 not upgraded.
# Need to get 2,481 kB of archives.
# After this operation, 2,754 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 python3-pip-whl all 22.0.2+dfsg-1ubuntu0.7 [1,683 kB]
# Get:2 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy/main amd64 python3-setuptools-whl all 68.1.2-2~jammy3 [792 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 python3.10-venv amd64 3.10.12-1~22.04.15 [5,714 B]
# Fetched 2,481 kB in 4s (703 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 3.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package python3-pip-whl.
# (Reading database ... 122354 files and directories currently installed.)
# Preparing to unpack .../python3-pip-whl_22.0.2+dfsg-1ubuntu0.7_all.deb ...
# Unpacking python3-pip-whl (22.0.2+dfsg-1ubuntu0.7) ...
# Selecting previously unselected package python3-setuptools-whl.
# Preparing to unpack .../python3-setuptools-whl_68.1.2-2~jammy3_all.deb ...
# Unpacking python3-setuptools-whl (68.1.2-2~jammy3) ...
# Selecting previously unselected package python3.10-venv.
# Preparing to unpack .../python3.10-venv_3.10.12-1~22.04.15_amd64.deb ...
# Unpacking python3.10-venv (3.10.12-1~22.04.15) ...
# Setting up python3-setuptools-whl (68.1.2-2~jammy3) ...
# Setting up python3-pip-whl (22.0.2+dfsg-1ubuntu0.7) ...
# Setting up python3.10-venv (3.10.12-1~22.04.15) ...
# Collecting pip
#   Downloading pip-26.0.1-py3-none-any.whl.metadata (4.7 kB)
# Collecting setuptools
#   Downloading setuptools-82.0.1-py3-none-any.whl.metadata (6.5 kB)
# Collecting wheel
#   Downloading wheel-0.46.3-py3-none-any.whl.metadata (2.4 kB)
# Collecting packaging>=24.0 (from wheel)
#   Downloading packaging-26.0-py3-none-any.whl.metadata (3.3 kB)
# Downloading pip-26.0.1-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 19.4 MB/s  0:00:00
# Downloading setuptools-82.0.1-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 22.4 MB/s  0:00:00
# Downloading wheel-0.46.3-py3-none-any.whl (30 kB)
# Downloading packaging-26.0-py3-none-any.whl (74 kB)
# Installing collected packages: setuptools, pip, packaging, wheel
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [wheel]
# Successfully installed packaging-26.0 pip-26.0.1 setuptools-82.0.1 wheel-0.46.3
# Python 3.10.12

# %% [markdown]
# # **Clone**

# %%
# %cd /content
# !git clone https://huggingface.co/spaces/k2-fsa/OmniVoice
# %cd OmniVoice
# Out:
# /content
# Cloning into 'OmniVoice'...
# remote: Enumerating objects: 102, done.
# remote: Counting objects: 100% (98/98), done.
# remote: Compressing objects: 100% (93/93), done.
# remote: Total 102 (delta 31), reused 0 (delta 0), pack-reused 4 (from 1)
# Receiving objects: 100% (102/102), 141.99 KiB | 6.76 MiB/s, done.
# Resolving deltas: 100% (31/31), done.
# /content/OmniVoice

# %% [markdown]
# # **Requirements**

# %%
# !python3.10 -m pip install -r requirements.txt
# !python3.10 -m pip install spaces
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu128
# Collecting torch==2.8.0 (from -r requirements.txt (line 2))
#   Downloading https://download-r2.pytorch.org/whl/cu128/torch-2.8.0%2Bcu128-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (30 kB)
# Collecting torchaudio==2.8.0 (from -r requirements.txt (line 3))
#   Downloading https://download-r2.pytorch.org/whl/cu128/torchaudio-2.8.0%2Bcu128-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (7.2 kB)
# Collecting transformers==5.3 (from -r requirements.txt (line 4))
#   Downloading transformers-5.3.0-py3-none-any.whl.metadata (32 kB)
# Collecting accelerate (from -r requirements.txt (line 5))
#   Downloading accelerate-1.13.0-py3-none-any.whl.metadata (19 kB)
# Collecting pydub (from -r requirements.txt (line 6))
#   Downloading pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting soundfile (from -r requirements.txt (line 7))
#   Downloading soundfile-0.13.1-py2.py3-none-manylinux_2_28_x86_64.whl.metadata (16 kB)
# Collecting numpy (from -r requirements.txt (line 8))
#   Downloading numpy-2.2.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Collecting gradio (from -r requirements.txt (line 9))
#   Downloading gradio-6.11.0-py3-none-any.whl.metadata (17 kB)
# Collecting hf_transfer (from -r requirements.txt (line 10))
#   Downloading hf_transfer-0.1.9-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.7 kB)
# Collecting filelock (from torch==2.8.0->-r requirements.txt (line 2))
#   Downloading filelock-3.25.2-py3-none-any.whl.metadata (2.0 kB)
# Collecting typing-extensions>=4.10.0 (from torch==2.8.0->-r requirements.txt (line 2))
#   Downloading https://download.pytorch.org/whl/typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting sympy>=1.13.3 (from torch==2.8.0->-r requirements.txt (line 2))
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx (from torch==2.8.0->-r requirements.txt (line 2))
#   Downloading networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Collecting jinja2 (from torch==2.8.0->-r requirements.txt (line 2))
#   Downloading https://download.pytorch.org/whl/jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting fsspec (from torch==2.8.0->-r requirements.txt (line 2))
#   Downloading fsspec-2026.3.0-py3-none-any.whl.metadata (10 kB)
# Collecting nvidia-cuda-nvrtc-cu12==12.8.93 (from torch==2.8.0->-r requirements.txt (line 2))
#   Downloading https://pypi.nvidia.com/nvidia-cuda-nvrtc-cu12/nvidia_cuda_nvrtc_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (88.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.0/88.0 MB 215.1 MB/s  0:00:00
# Collecting nvidia-cuda-runtime-cu12==12.8.90 (from torch==2.8.0->-r requirements.txt (line 2))
#   Downloading https://pypi.nvidia.com/nvidia-cuda-runtime-cu12/nvidia_cuda_runtime_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (954 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 954.8/954.8 kB 420.4 MB/s  0:00:00
# Collecting nvidia-cuda-cupti-cu12==12.8.90 (from torch==2.8.0->-r requirements.txt (line 2))
#   Downloading https://pypi.nvidia.com/nvidia-cuda-cupti-cu12/nvidia_cuda_cupti_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (10.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 356.4 MB/s  0:00:00
# Collecting nvidia-cudnn-cu12==9.10.2.21 (from torch==2.8.0->-r requirements.txt (line 2))
#   Downloading https://pypi.nvidia.com/nvidia-cudnn-cu12/nvidia_cudnn_cu12-9.10.2.21-py3-none-manylinux_2_27_x86_64.whl (706.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 706.8/706.8 MB 147.6 MB/s  0:00:09
# Collecting nvidia-cublas-cu12==12.8.4.1 (from torch==2.8.0->-r requirements.txt (line 2))
#   Downloading https://pypi.nvidia.com/nvidia-cublas-cu12/nvidia_cublas_cu12-12.8.4.1-py3-none-manylinux_2_27_x86_64.whl (594.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 594.3/594.3 MB 65.2 MB/s  0:00:08
# Collecting nvidia-cufft-cu12==11.3.3.83 (from torch==2.8.0->-r requirements.txt (line 2))
#   Downloading https://pypi.nvidia.com/nvidia-cufft-cu12/nvidia_cufft_cu12-11.3.3.83-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (193.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.1/193.1 MB 224.0 MB/s  0:00:00
# Collecting nvidia-curand-cu12==10.3.9.90 (from torch==2.8.0->-r requirements.txt (line 2))
#   Downloading https://pypi.nvidia.com/nvidia-curand-cu12/nvidia_curand_cu12-10.3.9.90-py3-none-manylinux_2_27_x86_64.whl (63.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.6/63.6 MB 253.9 MB/s  0:00:00
# Collecting nvidia-cusolver-cu12==11.7.3.90 (from torch==2.8.0->-r requirements.txt (line 2))
#   Downloading https://pypi.nvidia.com/nvidia-cusolver-cu12/nvidia_cusolver_cu12-11.7.3.90-py3-none-manylinux_2_27_x86_64.whl (267.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 267.5/267.5 MB 166.5 MB/s  0:00:01
# Collecting nvidia-cusparse-cu12==12.5.8.93 (from torch==2.8.0->-r requirements.txt (line 2))
#   Downloading https://pypi.nvidia.com/nvidia-cusparse-cu12/nvidia_cusparse_cu12-12.5.8.93-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (288.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.2/288.2 MB 74.3 MB/s  0:00:03
# Collecting nvidia-cusparselt-cu12==0.7.1 (from torch==2.8.0->-r requirements.txt (line 2))
#   Downloading https://pypi.nvidia.com/nvidia-cusparselt-cu12/nvidia_cusparselt_cu12-0.7.1-py3-none-manylinux2014_x86_64.whl (287.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 287.2/287.2 MB 151.4 MB/s  0:00:01
# Collecting nvidia-nccl-cu12==2.27.3 (from torch==2.8.0->-r requirements.txt (line 2))
#   Downloading https://pypi.nvidia.com/nvidia-nccl-cu12/nvidia_nccl_cu12-2.27.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (322.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.4/322.4 MB 76.4 MB/s  0:00:03
# Collecting nvidia-nvtx-cu12==12.8.90 (from torch==2.8.0->-r requirements.txt (line 2))
#   Downloading https://pypi.nvidia.com/nvidia-nvtx-cu12/nvidia_nvtx_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89 kB)
# Collecting nvidia-nvjitlink-cu12==12.8.93 (from torch==2.8.0->-r requirements.txt (line 2))
#   Downloading https://pypi.nvidia.com/nvidia-nvjitlink-cu12/nvidia_nvjitlink_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (39.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.3/39.3 MB 296.7 MB/s  0:00:00
# Collecting nvidia-cufile-cu12==1.13.1.3 (from torch==2.8.0->-r requirements.txt (line 2))
#   Downloading https://pypi.nvidia.com/nvidia-cufile-cu12/nvidia_cufile_cu12-1.13.1.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 396.9 MB/s  0:00:00
# Collecting triton==3.4.0 (from torch==2.8.0->-r requirements.txt (line 2))
#   Downloading https://download-r2.pytorch.org/whl/triton-3.4.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.7 kB)
# Collecting huggingface-hub<2.0,>=1.3.0 (from transformers==5.3->-r requirements.txt (line 4))
#   Downloading huggingface_hub-1.9.2-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers==5.3->-r requirements.txt (line 4)) (26.0)
# Collecting pyyaml>=5.1 (from transformers==5.3->-r requirements.txt (line 4))
#   Downloading pyyaml-6.0.3-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (2.4 kB)
# Collecting regex!=2019.12.17 (from transformers==5.3->-r requirements.txt (line 4))
#   Downloading regex-2026.4.4-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (40 kB)
# Collecting tokenizers<=0.23.0,>=0.22.0 (from transformers==5.3->-r requirements.txt (line 4))
#   Downloading tokenizers-0.22.2-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.3 kB)
# Collecting typer (from transformers==5.3->-r requirements.txt (line 4))
#   Downloading typer-0.24.1-py3-none-any.whl.metadata (16 kB)
# Collecting safetensors>=0.4.3 (from transformers==5.3->-r requirements.txt (line 4))
#   Downloading safetensors-0.7.0-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.1 kB)
# Collecting tqdm>=4.27 (from transformers==5.3->-r requirements.txt (line 4))
#   Downloading tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: setuptools>=40.8.0 in /usr/local/lib/python3.10/dist-packages (from triton==3.4.0->torch==2.8.0->-r requirements.txt (line 2)) (82.0.1)
# Collecting hf-xet<2.0.0,>=1.4.3 (from huggingface-hub<2.0,>=1.3.0->transformers==5.3->-r requirements.txt (line 4))
#   Downloading hf_xet-1.4.3-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (4.9 kB)
# Collecting httpx<1,>=0.23.0 (from huggingface-hub<2.0,>=1.3.0->transformers==5.3->-r requirements.txt (line 4))
#   Downloading httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting anyio (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers==5.3->-r requirements.txt (line 4))
#   Downloading anyio-4.13.0-py3-none-any.whl.metadata (4.5 kB)
# Collecting certifi (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers==5.3->-r requirements.txt (line 4))
#   Downloading certifi-2026.2.25-py3-none-any.whl.metadata (2.5 kB)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers==5.3->-r requirements.txt (line 4))
#   Downloading httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Collecting idna (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers==5.3->-r requirements.txt (line 4))
#   Downloading idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting h11>=0.16 (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers==5.3->-r requirements.txt (line 4))
#   Downloading h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting psutil (from accelerate->-r requirements.txt (line 5))
#   Downloading psutil-7.2.2-cp36-abi3-manylinux2010_x86_64.manylinux_2_12_x86_64.manylinux_2_28_x86_64.whl.metadata (22 kB)
# Collecting cffi>=1.0 (from soundfile->-r requirements.txt (line 7))
#   Downloading cffi-2.0.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.6 kB)
# Collecting aiofiles<25.0,>=22.0 (from gradio->-r requirements.txt (line 9))
#   Downloading aiofiles-24.1.0-py3-none-any.whl.metadata (10 kB)
# Collecting brotli>=1.1.0 (from gradio->-r requirements.txt (line 9))
#   Downloading brotli-1.2.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (6.1 kB)
# Collecting fastapi<1.0,>=0.115.2 (from gradio->-r requirements.txt (line 9))
#   Downloading fastapi-0.135.3-py3-none-any.whl.metadata (28 kB)
# Collecting ffmpy (from gradio->-r requirements.txt (line 9))
#   Downloading ffmpy-1.0.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting gradio-client==2.4.0 (from gradio->-r requirements.txt (line 9))
#   Downloading gradio_client-2.4.0-py3-none-any.whl.metadata (7.1 kB)
# Collecting groovy~=0.1 (from gradio->-r requirements.txt (line 9))
#   Downloading groovy-0.1.2-py3-none-any.whl.metadata (6.1 kB)
# Collecting hf-gradio<1.0,>=0.3.0 (from gradio->-r requirements.txt (line 9))
#   Downloading hf_gradio-0.3.0-py3-none-any.whl.metadata (404 bytes)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in /usr/lib/python3/dist-packages (from gradio->-r requirements.txt (line 9)) (2.0.1)
# Collecting orjson~=3.0 (from gradio->-r requirements.txt (line 9))
#   Downloading orjson-3.11.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (41 kB)
# Collecting pandas<4.0,>=1.0 (from gradio->-r requirements.txt (line 9))
#   Downloading pandas-2.3.3-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (91 kB)
# Collecting pillow<13.0,>=8.0 (from gradio->-r requirements.txt (line 9))
#   Downloading pillow-12.2.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.8 kB)
# Collecting pydantic<=3.0,>=2.0 (from gradio->-r requirements.txt (line 9))
#   Downloading pydantic-2.12.5-py3-none-any.whl.metadata (90 kB)
# Collecting python-multipart>=0.0.18 (from gradio->-r requirements.txt (line 9))
#   Downloading python_multipart-0.0.24-py3-none-any.whl.metadata (1.8 kB)
# Collecting pytz>=2017.2 (from gradio->-r requirements.txt (line 9))
#   Downloading pytz-2026.1.post1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting safehttpx<0.2.0,>=0.1.7 (from gradio->-r requirements.txt (line 9))
#   Downloading safehttpx-0.1.7-py3-none-any.whl.metadata (4.2 kB)
# Collecting semantic-version~=2.0 (from gradio->-r requirements.txt (line 9))
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Collecting starlette<2.0,>=0.40.0 (from gradio->-r requirements.txt (line 9))
#   Downloading starlette-1.0.0-py3-none-any.whl.metadata (6.3 kB)
# Collecting tomlkit<0.14.0,>=0.12.0 (from gradio->-r requirements.txt (line 9))
#   Downloading tomlkit-0.13.3-py3-none-any.whl.metadata (2.8 kB)
# Collecting uvicorn>=0.14.0 (from gradio->-r requirements.txt (line 9))
#   Downloading uvicorn-0.44.0-py3-none-any.whl.metadata (6.7 kB)
# Collecting exceptiongroup>=1.0.2 (from anyio->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers==5.3->-r requirements.txt (line 4))
#   Downloading exceptiongroup-1.3.1-py3-none-any.whl.metadata (6.7 kB)
# Collecting typing-inspection>=0.4.2 (from fastapi<1.0,>=0.115.2->gradio->-r requirements.txt (line 9))
#   Downloading typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting annotated-doc>=0.0.2 (from fastapi<1.0,>=0.115.2->gradio->-r requirements.txt (line 9))
#   Downloading annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# Collecting python-dateutil>=2.8.2 (from pandas<4.0,>=1.0->gradio->-r requirements.txt (line 9))
#   Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting tzdata>=2022.7 (from pandas<4.0,>=1.0->gradio->-r requirements.txt (line 9))
#   Downloading tzdata-2026.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<=3.0,>=2.0->gradio->-r requirements.txt (line 9))
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.41.5 (from pydantic<=3.0,>=2.0->gradio->-r requirements.txt (line 9))
#   Downloading pydantic_core-2.41.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.3 kB)
# Collecting click>=8.2.1 (from typer->transformers==5.3->-r requirements.txt (line 4))
#   Downloading click-8.3.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting shellingham>=1.3.0 (from typer->transformers==5.3->-r requirements.txt (line 4))
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting rich>=12.3.0 (from typer->transformers==5.3->-r requirements.txt (line 4))
#   Downloading rich-14.3.3-py3-none-any.whl.metadata (18 kB)
# Collecting pycparser (from cffi>=1.0->soundfile->-r requirements.txt (line 7))
#   Downloading pycparser-3.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas<4.0,>=1.0->gradio->-r requirements.txt (line 9)) (1.16.0)
# Collecting markdown-it-py>=2.2.0 (from rich>=12.3.0->typer->transformers==5.3->-r requirements.txt (line 4))
#   Downloading markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Collecting pygments<3.0.0,>=2.13.0 (from rich>=12.3.0->typer->transformers==5.3->-r requirements.txt (line 4))
#   Downloading pygments-2.20.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->transformers==5.3->-r requirements.txt (line 4))
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch==2.8.0->-r requirements.txt (line 2))
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Downloading https://download-r2.pytorch.org/whl/cu128/torch-2.8.0%2Bcu128-cp310-cp310-manylinux_2_28_x86_64.whl (889.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 889.1/889.1 MB 29.1 MB/s  0:00:17
# Downloading https://download-r2.pytorch.org/whl/cu128/torchaudio-2.8.0%2Bcu128-cp310-cp310-manylinux_2_28_x86_64.whl (3.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 119.1 MB/s  0:00:00
# Downloading transformers-5.3.0-py3-none-any.whl (10.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 33.1 MB/s  0:00:00
# Downloading https://download-r2.pytorch.org/whl/triton-3.4.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (155.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.4/155.4 MB 67.6 MB/s  0:00:02
# Downloading huggingface_hub-1.9.2-py3-none-any.whl (637 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 637.3/637.3 kB 28.9 MB/s  0:00:00
# Downloading hf_xet-1.4.3-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (4.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 70.1 MB/s  0:00:00
# Downloading httpx-0.28.1-py3-none-any.whl (73 kB)
# Downloading httpcore-1.0.9-py3-none-any.whl (78 kB)
# Downloading tokenizers-0.22.2-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 80.9 MB/s  0:00:00
# Downloading accelerate-1.13.0-py3-none-any.whl (383 kB)
# Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Downloading soundfile-0.13.1-py2.py3-none-manylinux_2_28_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 37.9 MB/s  0:00:00
# Downloading numpy-2.2.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.8/16.8 MB 115.6 MB/s  0:00:00
# Downloading gradio-6.11.0-py3-none-any.whl (36.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.8/36.8 MB 51.7 MB/s  0:00:00
# Downloading gradio_client-2.4.0-py3-none-any.whl (59 kB)
# Downloading aiofiles-24.1.0-py3-none-any.whl (15 kB)
# Downloading anyio-4.13.0-py3-none-any.whl (114 kB)
# Downloading fastapi-0.135.3-py3-none-any.whl (117 kB)
# Downloading groovy-0.1.2-py3-none-any.whl (14 kB)
# Downloading hf_gradio-0.3.0-py3-none-any.whl (4.2 kB)
# Downloading https://download.pytorch.org/whl/jinja2-3.1.6-py3-none-any.whl (134 kB)
# Downloading orjson-3.11.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (133 kB)
# Downloading pandas-2.3.3-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (12.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 148.6 MB/s  0:00:00
# Downloading pillow-12.2.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (7.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 141.7 MB/s  0:00:00
# Downloading pydantic-2.12.5-py3-none-any.whl (463 kB)
# Downloading pydantic_core-2.41.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 107.2 MB/s  0:00:00
# Downloading pyyaml-6.0.3-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (770 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 770.3/770.3 kB 45.7 MB/s  0:00:00
# Downloading safehttpx-0.1.7-py3-none-any.whl (9.0 kB)
# Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Downloading starlette-1.0.0-py3-none-any.whl (72 kB)
# Downloading tomlkit-0.13.3-py3-none-any.whl (38 kB)
# Downloading typer-0.24.1-py3-none-any.whl (56 kB)
# Downloading https://download.pytorch.org/whl/typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Downloading hf_transfer-0.1.9-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 143.4 MB/s  0:00:00
# Downloading annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading brotli-1.2.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 93.7 MB/s  0:00:00
# Downloading cffi-2.0.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (216 kB)
# Downloading click-8.3.2-py3-none-any.whl (108 kB)
# Downloading exceptiongroup-1.3.1-py3-none-any.whl (16 kB)
# Downloading filelock-3.25.2-py3-none-any.whl (26 kB)
# Downloading fsspec-2026.3.0-py3-none-any.whl (202 kB)
# Downloading h11-0.16.0-py3-none-any.whl (37 kB)
# Downloading idna-3.11-py3-none-any.whl (71 kB)
# Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Downloading python_multipart-0.0.24-py3-none-any.whl (24 kB)
# Downloading pytz-2026.1.post1-py2.py3-none-any.whl (510 kB)
# Downloading regex-2026.4.4-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (793 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 793.6/793.6 kB 50.4 MB/s  0:00:00
# Downloading rich-14.3.3-py3-none-any.whl (310 kB)
# Downloading pygments-2.20.0-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 83.2 MB/s  0:00:00
# Downloading markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading safetensors-0.7.0-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (507 kB)
# Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 119.4 MB/s  0:00:00
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 24.7 MB/s  0:00:00
# Downloading tqdm-4.67.3-py3-none-any.whl (78 kB)
# Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Downloading tzdata-2026.1-py2.py3-none-any.whl (348 kB)
# Downloading uvicorn-0.44.0-py3-none-any.whl (69 kB)
# Downloading certifi-2026.2.25-py3-none-any.whl (153 kB)
# Downloading ffmpy-1.0.0-py3-none-any.whl (5.6 kB)
# Downloading networkx-3.4.2-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 81.0 MB/s  0:00:00
# Downloading psutil-7.2.2-cp36-abi3-manylinux2010_x86_64.manylinux_2_12_x86_64.manylinux_2_28_x86_64.whl (155 kB)
# Downloading pycparser-3.0-py3-none-any.whl (48 kB)
# Installing collected packages: pytz, pydub, nvidia-cusparselt-cu12, mpmath, brotli, tzdata, typing-extensions, triton, tqdm, tomlkit, sympy, shellingham, semantic-version, safetensors, regex, pyyaml, python-multipart, python-dateutil, pygments, pycparser, psutil, pillow, orjson, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufile-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, networkx, mdurl, jinja2, idna, hf-xet, hf_transfer, h11, groovy, fsspec, filelock, ffmpy, click, certifi, annotated-types, annotated-doc, aiofiles, uvicorn, typing-inspection, pydantic-core, pandas, nvidia-cusparse-cu12, nvidia-cufft-cu12, nvidia-cudnn-cu12, markdown-it-py, httpcore, exceptiongroup, cffi, soundfile, rich, pydantic, nvidia-cusolver-cu12, anyio, typer, torch, starlette, httpx, torchaudio, safehttpx, huggingface-hub, fastapi, tokenizers, gradio-client, accelerate, transformers, hf-gradio, gradio
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79/79 [gradio]
# Successfully installed accelerate-1.13.0 aiofiles-24.1.0 annotated-doc-0.0.4 annotated-types-0.7.0 anyio-4.13.0 brotli-1.2.0 certifi-2026.2.25 cffi-2.0.0 click-8.3.2 exceptiongroup-1.3.1 fastapi-0.135.3 ffmpy-1.0.0 filelock-3.25.2 fsspec-2026.3.0 gradio-6.11.0 gradio-client-2.4.0 groovy-0.1.2 h11-0.16.0 hf-gradio-0.3.0 hf-xet-1.4.3 hf_transfer-0.1.9 httpcore-1.0.9 httpx-0.28.1 huggingface-hub-1.9.2 idna-3.11 jinja2-3.1.6 markdown-it-py-4.0.0 mdurl-0.1.2 mpmath-1.3.0 networkx-3.4.2 numpy-2.2.6 nvidia-cublas-cu12-12.8.4.1 nvidia-cuda-cupti-cu12-12.8.90 nvidia-cuda-nvrtc-cu12-12.8.93 nvidia-cuda-runtime-cu12-12.8.90 nvidia-cudnn-cu12-9.10.2.21 nvidia-cufft-cu12-11.3.3.83 nvidia-cufile-cu12-1.13.1.3 nvidia-curand-cu12-10.3.9.90 nvidia-cusolver-cu12-11.7.3.90 nvidia-cusparse-cu12-12.5.8.93 nvidia-cusparselt-cu12-0.7.1 nvidia-nccl-cu12-2.27.3 nvidia-nvjitlink-cu12-12.8.93 nvidia-nvtx-cu12-12.8.90 orjson-3.11.8 pandas-2.3.3 pillow-12.2.0 psutil-7.2.2 pycparser-3.0 pydantic-2.12.5 pydantic-core-2.41.5 pydub-0.25.1 pygments-2.20.0 python-dateutil-2.9.0.post0 python-multipart-0.0.24 pytz-2026.1.post1 pyyaml-6.0.3 regex-2026.4.4 rich-14.3.3 safehttpx-0.1.7 safetensors-0.7.0 semantic-version-2.10.0 shellingham-1.5.4 soundfile-0.13.1 starlette-1.0.0 sympy-1.14.0 tokenizers-0.22.2 tomlkit-0.13.3 torch-2.8.0+cu128 torchaudio-2.8.0+cu128 tqdm-4.67.3 transformers-5.3.0 triton-3.4.0 typer-0.24.1 typing-extensions-4.15.0 typing-inspection-0.4.2 tzdata-2026.1 uvicorn-0.44.0
# Collecting spaces
#   Downloading spaces-0.48.1-py3-none-any.whl.metadata (1.0 kB)
# Requirement already satisfied: gradio in /usr/local/lib/python3.10/dist-packages (from spaces) (6.11.0)
# Requirement already satisfied: httpx>=0.20 in /usr/local/lib/python3.10/dist-packages (from spaces) (0.28.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from spaces) (26.0)
# Collecting psutil<6,>=2 (from spaces)
#   Downloading psutil-5.9.8-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (21 kB)
# Requirement already satisfied: pydantic<3,>=1 in /usr/local/lib/python3.10/dist-packages (from spaces) (2.12.5)
# Collecting requests<3.0,>=2.19 (from spaces)
#   Downloading requests-2.33.1-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: typing-extensions<5,>=4 in /usr/local/lib/python3.10/dist-packages (from spaces) (4.15.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->spaces) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->spaces) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->spaces) (0.4.2)
# Collecting charset_normalizer<4,>=2 (from requests<3.0,>=2.19->spaces)
#   Downloading charset_normalizer-3.4.7-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (40 kB)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.19->spaces) (3.11)
# Collecting urllib3<3,>=1.26 (from requests<3.0,>=2.19->spaces)
#   Downloading urllib3-2.6.3-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: certifi>=2023.5.7 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.19->spaces) (2026.2.25)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.20->spaces) (4.13.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx>=0.20->spaces) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx>=0.20->spaces) (0.16.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /usr/local/lib/python3.10/dist-packages (from anyio->httpx>=0.20->spaces) (1.3.1)
# Requirement already satisfied: aiofiles<25.0,>=22.0 in /usr/local/lib/python3.10/dist-packages (from gradio->spaces) (24.1.0)
# Requirement already satisfied: brotli>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from gradio->spaces) (1.2.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in /usr/local/lib/python3.10/dist-packages (from gradio->spaces) (0.135.3)
# Requirement already satisfied: ffmpy in /usr/local/lib/python3.10/dist-packages (from gradio->spaces) (1.0.0)
# Requirement already satisfied: gradio-client==2.4.0 in /usr/local/lib/python3.10/dist-packages (from gradio->spaces) (2.4.0)
# Requirement already satisfied: groovy~=0.1 in /usr/local/lib/python3.10/dist-packages (from gradio->spaces) (0.1.2)
# Requirement already satisfied: hf-gradio<1.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from gradio->spaces) (0.3.0)
# Requirement already satisfied: huggingface-hub<2.0,>=0.33.5 in /usr/local/lib/python3.10/dist-packages (from gradio->spaces) (1.9.2)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.10/dist-packages (from gradio->spaces) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in /usr/lib/python3/dist-packages (from gradio->spaces) (2.0.1)
# Requirement already satisfied: numpy<3.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from gradio->spaces) (2.2.6)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.10/dist-packages (from gradio->spaces) (3.11.8)
# Requirement already satisfied: pandas<4.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from gradio->spaces) (2.3.3)
# Requirement already satisfied: pillow<13.0,>=8.0 in /usr/local/lib/python3.10/dist-packages (from gradio->spaces) (12.2.0)
# Requirement already satisfied: pydub in /usr/local/lib/python3.10/dist-packages (from gradio->spaces) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in /usr/local/lib/python3.10/dist-packages (from gradio->spaces) (0.0.24)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.10/dist-packages (from gradio->spaces) (2026.1.post1)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /usr/local/lib/python3.10/dist-packages (from gradio->spaces) (6.0.3)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.7 in /usr/local/lib/python3.10/dist-packages (from gradio->spaces) (0.1.7)
# Requirement already satisfied: semantic-version~=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio->spaces) (2.10.0)
# Requirement already satisfied: starlette<2.0,>=0.40.0 in /usr/local/lib/python3.10/dist-packages (from gradio->spaces) (1.0.0)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in /usr/local/lib/python3.10/dist-packages (from gradio->spaces) (0.13.3)
# Requirement already satisfied: typer<1.0,>=0.12 in /usr/local/lib/python3.10/dist-packages (from gradio->spaces) (0.24.1)
# Requirement already satisfied: uvicorn>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from gradio->spaces) (0.44.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from gradio-client==2.4.0->gradio->spaces) (2026.3.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.10/dist-packages (from fastapi<1.0,>=0.115.2->gradio->spaces) (0.0.4)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<2.0,>=0.33.5->gradio->spaces) (3.25.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<2.0,>=0.33.5->gradio->spaces) (1.4.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<2.0,>=0.33.5->gradio->spaces) (4.67.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas<4.0,>=1.0->gradio->spaces) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas<4.0,>=1.0->gradio->spaces) (2026.1)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.10/dist-packages (from typer<1.0,>=0.12->gradio->spaces) (8.3.2)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0,>=0.12->gradio->spaces) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0,>=0.12->gradio->spaces) (14.3.3)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas<4.0,>=1.0->gradio->spaces) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=12.3.0->typer<1.0,>=0.12->gradio->spaces) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=12.3.0->typer<1.0,>=0.12->gradio->spaces) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer<1.0,>=0.12->gradio->spaces) (0.1.2)
# Downloading spaces-0.48.1-py3-none-any.whl (106 kB)
# Downloading psutil-5.9.8-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (288 kB)
# Downloading requests-2.33.1-py3-none-any.whl (64 kB)
# Downloading charset_normalizer-3.4.7-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (216 kB)
# Downloading urllib3-2.6.3-py3-none-any.whl (131 kB)
# Installing collected packages: urllib3, psutil, charset_normalizer, requests, spaces
#   Attempting uninstall: psutil
#     Found existing installation: psutil 7.2.2
#     Uninstalling psutil-7.2.2:
#       Successfully uninstalled psutil-7.2.2
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5/5 [spaces]
# Successfully installed charset_normalizer-3.4.7 psutil-5.9.8 requests-2.33.1 spaces-0.48.1 urllib3-2.6.3

# %% [markdown]
# # **FFMPEG**

# %%
# !apt-get update -qq
# !apt-get install -y ffmpeg
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 70 not upgraded.

# %% [markdown]
# # **Change in App File**

# %%
# Update app.py launch line to add share=True

file_path = "app.py"   # change path if app.py is in another folder

with open(file_path, "r", encoding="utf-8") as f:
    content = f.read()

content = content.replace(
    "demo.queue().launch()",
    "demo.queue().launch(share=True)"
)

with open(file_path, "w", encoding="utf-8") as f:
    f.write(content)

print("✅ app.py updated successfully with share=True")
# Out:
# ✅ app.py updated successfully with share=True

# %%
file_path = "/content/OmniVoice/omnivoice/models/omnivoice.py"

with open(file_path, "r") as f:
    code = f.read()

old = 'return self._asr_pipe(audio_input)["text"].strip()'

new = '''import numpy as np
        if isinstance(audio_input, dict):
            audio_array = np.array(audio_input["array"], dtype=np.float32)
            sr = audio_input["sampling_rate"]
        else:
            audio_array = np.array(audio_input[0], dtype=np.float32)
            sr = audio_input[1]
        return self._asr_pipe({"array": audio_array, "sampling_rate": sr})["text"].strip()'''

code = code.replace(old, new)

with open(file_path, "w") as f:
    f.write(code)

print("Patch applied correctly ✅")
# Out:
# Patch applied correctly ✅

# %% [markdown]
# # **Main Code**

# %%
# !python3.10 app.py
# Out:
# Loading model from k2-fsa/OmniVoice to cuda ...
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# 2026-04-08 22:14:27,841 huggingface_hub.utils._http WARNING: Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json: 2.24kB [00:00, 7.30MB/s]
# model.safetensors: 100% 2.45G/2.45G [00:24<00:00, 101MB/s]
# Loading weights: 100% 313/313 [00:00<00:00, 376.75it/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Downloading (incomplete total...):   0% 16.7k/806M [00:00<3:01:42, 73.9kB/s]
# Downloading (incomplete total...): 817MB [00:03, 290MB/s]
# Fetching 13 files: 100% 13/13 [00:03<00:00,  3.48it/s]
# Download complete: : 817MB [00:04, 195MB/s]
# Loading weights: 100% 527/527 [00:00<00:00, 1954.38it/s]
# config.json: 1.26kB [00:00, 4.15MB/s]
# model.safetensors: 100% 1.62G/1.62G [00:09<00:00, 176MB/s]
# Loading weights: 100% 587/587 [00:00<00:00, 1133.39it/s]
# generation_config.json: 3.77kB [00:00, 14.1MB/s]
# tokenizer_config.json: 283kB [00:00, 186MB/s]
# vocab.json: 1.04MB [00:00, 44.1MB/s]
# tokenizer.json: 2.71MB [00:00, 131MB/s]
# merges.txt: 494kB [00:00, 79.2MB/s]
# normalizer.json: 52.7kB [00:00, 72.0MB/s]
# added_tokens.json: 34.6kB [00:00, 69.0MB/s]
# special_tokens_map.json: 2.19kB [00:00, 7.59MB/s]
# preprocessor_config.json: 100% 340/340 [00:00<00:00, 1.23MB/s]
# Model loaded successfully!
# /content/OmniVoice/omnivoice/cli/demo.py:301: UserWarning: The parameters have been moved from the Blocks constructor to the launch() method in Gradio 6.0: theme, css. Please pass these parameters to launch() instead.
#   with gr.Blocks(theme=theme, css=css, title="OmniVoice Demo") as demo:
# * Running on local URL:  http://127.0.0.1:7860
# * Running on public URL: https://fbb2c0d0c6b76c24ba.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# Using custom `forced_decoder_ids` from the (generation) config. This is deprecated in favor of the `task` and `language` flags/config options.
# Transcription using a multilingual Whisper will default to language detection followed by transcription instead of translation to English. This might be a breaking change for your use case. If you want to instead always translate your audio to English, make sure to pass `language='en'`. See https://github.com/huggingface/transformers/pull/28687 for more details.
# A custom logits processor of type <class 'transformers.generation.logits_process.SuppressTokensLogitsProcessor'> has been passed to `.generate()`, but it was also created in `.generate()`, given its parameterization. The custom <class 'transformers.generation.logits_process.SuppressTokensLogitsProcessor'> will take precedence. Please check the docstring of <class 'transformers.generation.logits_process.SuppressTokensLogitsProcessor'> to see related `.generate()` flags.
# A custom logits processor of type <class 'transformers.generation.logits_process.SuppressTokensAtBeginLogitsProcessor'> has been passed to `.generate()`, but it was also created in `.generate()`, given its parameterization. The custom <class 'transformers.generation.logits_process.SuppressTokensAtBeginLogitsProcessor'> will take precedence. Please check the docstring of <class 'transformers.generation.logits_process.SuppressTokensAtBeginLogitsProcessor'> to see related `.generate()` flags.
# 2026-04-08 22:28:03,278 omnivoice.models.omnivoice DEBUG: Auto-transcribed ref_text: y recogemos los pañales, etcétera, etcétera. ¿Listo? Entonces avísanos cómo le queda mejor. El último es que si vienen acá, entonces ahí toca decirles a la abuela porque su mamá a veces va y la cuida los fines de semana.
# 2026-04-08 22:28:03,818 omnivoice.models.omnivoice DEBUG: Item 0 chunked into 6 pieces: ['Hay principios que considero fundamentales en mi manera de relacionarme con los demás. Estos valores han sido forjados tanto en la crianza recibida de mis padres como en las distintas instituciones que hicieron parte de mi proceso de formación.', 'Entre ellos destaco los siguientes:\n\nEl servicio: Mantener una actitud permanente de colaboración hacia los demás, de manera desinteresada. Este principio guarda coherencia con el lema lasallista de la institución que me formó como educador:', '“Educar para pensar, decidir y servir”. Como bien dice el refrán: “El que no vive para servir, no sirve para vivir”.\n\nLa opción por los demás: Tener una especial sensibilidad hacia quienes más lo necesitan: los pobres, los iletrados y los débiles,', 'tanto en lo físico como en lo espiritual. Una de mis constantes peticiones a Dios es que me conceda sabiduría para comprender a las personas y así poder ayudarlas de la mejor manera.\n\nLa nobleza: Ser sincero,', 'tener sensibilidad para escuchar a los demás, actuar con generosidad y mantener una actitud justa frente a la verdad; es decir, ser amante de la verdad y de la justicia.\n\nEspero que, mediante esta etopeya,', 'puedan conocer un poco más de mi forma de ser y de pensar.']
# 2026-04-08 22:28:03,819 omnivoice.models.omnivoice DEBUG: Item 0 — text: Hay principios que considero fundamentales en mi manera de relacionarme con los demás. Estos valores han sido forjados tanto en la crianza recibida de mis padres como en las distintas instituciones que hicieron parte de mi proceso de formación. | ref_text: y recogemos los pañales, etcétera, etcétera. ¿Listo? Entonces avísanos cómo le queda mejor. El último es que si vienen acá, entonces ahí toca decirles a la abuela porque su mamá a veces va y la cuida los fines de semana. | instruct: None | lang: es | target_tokens: 366
# 2026-04-08 22:28:09,044 omnivoice.models.omnivoice DEBUG: Item 0 — text: Entre ellos destaco los siguientes:
#
# El servicio: Mantener una actitud permanente de colaboración hacia los demás, de manera desinteresada. Este principio guarda coherencia con el lema lasallista de la institución que me formó como educador: | ref_text: y recogemos los pañales, etcétera, etcétera. ¿Listo? Entonces avísanos cómo le queda mejor. El último es que si vienen acá, entonces ahí toca decirles a la abuela porque su mamá a veces va y la cuida los fines de semana. | instruct: None | lang: es | target_tokens: 366
# 2026-04-08 22:28:14,304 omnivoice.models.omnivoice DEBUG: Item 0 — text: “Educar para pensar, decidir y servir”. Como bien dice el refrán: “El que no vive para servir, no sirve para vivir”.
#
# La opción por los demás: Tener una especial sensibilidad hacia quienes más lo necesitan: los pobres, los iletrados y los débiles, | ref_text: y recogemos los pañales, etcétera, etcétera. ¿Listo? Entonces avísanos cómo le queda mejor. El último es que si vienen acá, entonces ahí toca decirles a la abuela porque su mamá a veces va y la cuida los fines de semana. | instruct: None | lang: es | target_tokens: 359
# 2026-04-08 22:28:19,557 omnivoice.models.omnivoice DEBUG: Item 0 — text: tanto en lo físico como en lo espiritual. Una de mis constantes peticiones a Dios es que me conceda sabiduría para comprender a las personas y así poder ayudarlas de la mejor manera.
#
# La nobleza: Ser sincero, | ref_text: y recogemos los pañales, etcétera, etcétera. ¿Listo? Entonces avísanos cómo le queda mejor. El último es que si vienen acá, entonces ahí toca decirles a la abuela porque su mamá a veces va y la cuida los fines de semana. | instruct: None | lang: es | target_tokens: 307
# 2026-04-08 22:28:24,387 omnivoice.models.omnivoice DEBUG: Item 0 — text: tener sensibilidad para escuchar a los demás, actuar con generosidad y mantener una actitud justa frente a la verdad; es decir, ser amante de la verdad y de la justicia.
#
# Espero que, mediante esta etopeya, | ref_text: y recogemos los pañales, etcétera, etcétera. ¿Listo? Entonces avísanos cómo le queda mejor. El último es que si vienen acá, entonces ahí toca decirles a la abuela porque su mamá a veces va y la cuida los fines de semana. | instruct: None | lang: es | target_tokens: 303
# 2026-04-08 22:28:29,192 omnivoice.models.omnivoice DEBUG: Item 0 — text: puedan conocer un poco más de mi forma de ser y de pensar. | ref_text: y recogemos los pañales, etcétera, etcétera. ¿Listo? Entonces avísanos cómo le queda mejor. El último es que si vienen acá, entonces ahí toca decirles a la abuela porque su mamá a veces va y la cuida los fines de semana. | instruct: None | lang: es | target_tokens: 82
