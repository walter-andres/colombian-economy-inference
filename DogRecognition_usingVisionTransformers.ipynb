# %% [markdown]
# 🐶 Dog Recognition in Video using Vision Transformers (ViT)
#
# 🎯 Objective
#
# The goal of this project is to accurately recognize and track dogs in video sequences using Vision Transformer (ViT) models. Leveraging the power of Transformer-based architectures, we aim to improve detection robustness in dynamic and complex scenes.
#
# 📌 Key Tasks (Modify)
#
# Frame extraction from videos.
# Preprocessing and annotation for dog detection.
# Fine-tuning a pretrained Vision Transformer model.
# Evaluation of detection performance on video datasets.
# 🧠 Model: Vision Transformer (ViT)
#
# Vision Transformers offer a powerful alternative to CNNs by treating images (or video frames) as sequences of patches, enabling better contextual understanding — especially useful in video data with motion and occlusion.
#
# 🛠 Tools & Frameworks
#
# Python 🐍
# PyTorch / TensorFlow
# OpenCV
# Hugging Face Transformers
# Kaggle Datasets

# %%
# !pip install transformers
# !pip install transformers torch

# %%
# !nvidia-smi
# Out:
# /bin/bash: line 1: nvidia-smi: command not found

# %%
import transformers
import torch

print("Transformers version:", transformers.__version__)
print("Torch version:", torch.__version__)
# Out:
# Transformers version: 4.55.4
# Torch version: 2.8.0+cu126

# %%
import transformers
import torch

print("Transformers version:", transformers.__version__)
print("Torch version:", torch.__version__)
